# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt
import torch

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances

# %%
dataset = 'coco2017'
annot_dir = './coco2017/annotations'
imgs_dir = './coco2017/{}2017'

for split in ['train', 'val']: 
    #if split == 'train':
        #annot_path = 'cityscapes/annotations/instancesonly_filtered_gtFine_train_temp.json'
    #else:
    annot_path = os.path.join(annot_dir, f'instances_{split}2017.json')
    d_name = dataset + f'_{split}'
    register_coco_instances(d_name, {}, annot_path, imgs_dir.format(split))

# Load dataset
dataset_dicts = DatasetCatalog.get('coco2017_val')
metadata = MetadataCatalog.get('coco2017_val')
# Out:
# [04/16 23:25:50 d2.data.datasets.coco]: Loaded 5000 images in COCO format from ./coco2017/annotations/instances_val2017.json

# %%
# Visualize random images with ground truth annotations
num_images_to_visualize = 3  # Adjust the number of images to visualize

_, axs = plt.subplots(nrows=num_images_to_visualize, figsize=(18, 18))

for i, d in enumerate(random.sample(dataset_dicts, num_images_to_visualize)):
    print(d["file_name"])

    im = cv2.imread(d["file_name"])

    print(im.shape)


    # Get ground truth annotations
    visualizer = Visualizer(im[:, :, ::-1], metadata=metadata, scale=0.8)
    vis = visualizer.draw_dataset_dict(d)

    # Plot the image with ground truth annotations
    axs[i].imshow(vis.get_image())
# Out:
# ./coco2017/val2017/000000554328.jpg
# (499, 640, 3)
# ./coco2017/val2017/000000415882.jpg
# (640, 544, 3)
# ./coco2017/val2017/000000149375.jpg
# (485, 640, 3)

# %%
import argparse

class Args(argparse.Namespace):
    config_file='khang_net/configs/huflit_net/huflit_net_se_1x.py'
    eval_only=False
    num_gpus=1
    num_machines=1
    resume=False

args = Args()

# %%
from detectron2.model_zoo import get_config
from detectron2.config import LazyConfig
from detectron2.config.instantiate import instantiate


cfg = LazyConfig.load("khang_net/configs/huflit_net/huflit_net_se_1x.py")
cfg.train.device = 'mps'
cfg.dataloader.evaluator.dataset_name = 'cityscapes_val'
cfg.dataloader.train.dataset.names = 'cityscapes_train'
cfg.dataloader.test.dataset.names = 'cityscapes_val'
cfg.dataloader.train.total_batch_size = 1

cfg.model.num_classes = 90
cfg.model.yolof.num_classes = 90
cfg.model.mask_head.num_classes = 90

# %%
huflit_net = instantiate(cfg.model)

# %%
from detectron2.checkpoint import DetectionCheckpointer

huflit_net.train(False)
DetectionCheckpointer(huflit_net).load('/Users/giakhang/Downloads/output/model_0000999.pth')
# Out:
# [04/16 23:15:58 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /Users/giakhang/Downloads/output/model_0000999.pth ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 from detectron2.checkpoint import DetectionCheckpointer
#       3 huflit_net.train(False)
# ----> 4 DetectionCheckpointer(huflit_net).load('/Users/giakhang/Downloads/output/model_0000999.pth')
#
# File ~/dev/work/sand_box/hope_to_public_net/detectron2/detectron2/checkpoint/detection_checkpoint.py:62, in DetectionCheckpointer.load(self, path, *args, **kwargs)
#      60     path = parsed_url._replace(query="").geturl()  # remove query from filename
#      61     path = self.path_manager.get_local_path(path)
# ---> 62 ret = super().load(path, *args, **kwargs)
#      64 if need_sync:
#      65     logger.info("Broadcasting model states from main worker ...")
#
# File ~/miniconda3/envs/hope_to_public_net/lib/python3.9/site-packages/fvcore/common/checkpoint.py:153, in Checkpointer.load(self, path, checkpointables)
#     151 if not os.path.isfile(path):
#     152     path = self.path_manager.get_local_path(path)
# --> 153     assert os.path.isfile(path), "Checkpoint {} not found!".format(path)
#     155 checkpoint = self._load_file(path)
#     156 incompatible = self._load_model(checkpoint)
#
# AssertionError: Checkpoint /Users/giakhang/Downloads/output/model_0000999.pth not found!

# %%
huflit_net.to('mps')
# Out:
# HUFLIT_Net(
#   (yolof): YOLOF(
#     (backbone): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): SEBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=16, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (1): SEBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=16, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=16, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): SEBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=32, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (1): SEBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=32, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=32, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (3): SEBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=32, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): SEBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (1): SEBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (3): SEBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (4): SEBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (5): SEBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): SEBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 2048, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 128, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (1): SEBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 2048, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 128, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#         (2): SEBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (channel_attention): ChannelAttention(
#             (squeeze): ModuleList(
#               (0): AdaptiveAvgPool2d(output_size=1)
#               (1): AdaptiveMaxPool2d(output_size=1)
#             )
#             (excitation): Sequential(
#               (0): Conv2d(
#                 2048, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#                 (activation): ReLU()
#               )
#               (1): Conv2d(
#                 128, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#                 (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#               )
#             )
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#     )
#     (encoder): DilatedEncoder(
#       (lateral_conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#       (lateral_norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#       (fpn_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (fpn_norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#       (dilated_encoder_blocks): Sequential(
#         (0): Bottleneck(
#           (conv1): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv2): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv3): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv2): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv3): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (conv1): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv2): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv3): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (3): Bottleneck(
#           (conv1): Sequential(
#             (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv2): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(8, 8), dilation=(8, 8))
#             (1): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#           (conv3): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#             (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (decoder): YOLOFDecoder(
#       (cls_subnet): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (5): ReLU(inplace=True)
#       )
#       (bbox_subnet): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (10): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         (11): ReLU(inplace=True)
#       )
#       (cls_score): Conv2d(512, 450, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bbox_pred): Conv2d(512, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (object_pred): Conv2d(512, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (anchor_generator): YOLOFAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (anchor_matcher): UniformMatcher()
#   )
#   (pooler): ROIPooler(
#     (level_poolers): ModuleList(
#       (0): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#     )
#   )
#   (mask_head): MaskRCNNConvUpsampleHead(
#     (spatial_attention): SpatialAttention(
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (sigmoid): Sigmoid()
#     )
#     (mask_fcn1): Conv2d(
#       512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation): ReLU()
#     )
#     (mask_fcn2): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation): ReLU()
#     )
#     (mask_fcn3): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation): ReLU()
#     )
#     (mask_fcn4): Conv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (activation): ReLU()
#     )
#     (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#     (predictor): Conv2d(256, 90, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
dataloader = instantiate(cfg.dataloader.train)
# show image
batch = next(iter(dataloader))
# Out:
# [03/23 16:40:13 d2.data.datasets.coco]: Loaded 1 images in COCO format from cityscapes/annotations/instancesonly_filtered_gtFine_train_temp.json
# [03/23 16:40:13 d2.data.build]: Removed 0 images with no usable annotations. 1 images left.
# [03/23 16:40:13 d2.data.build]: Distribution of instances among all 8 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   person   | 14           |    car     | 9            |   truck    | 0            |
# |   rider    | 0            | motorcycle | 0            |  bicycle   | 4            |
# |    bus     | 2            |   train    | 0            |            |              |
# |   total    | 29           |            |              |            |              |
# [03/23 16:40:13 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=[800], max_size=1333, sample_style='choice'), RandomFlip()]
# [03/23 16:40:13 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/23 16:40:13 d2.data.common]: Serializing 1 elements to byte tensors and concatenating them all ...
# [03/23 16:40:13 d2.data.common]: Serialized dataset takes 0.05 MiB
# [03/23 16:40:13 d2.data.build]: Making batched data loader with batch_size=1

# %%
results = huflit_net(batch)
# Out:
# /Users/giakhang/miniconda3/envs/hope_to_public_net/lib/python3.9/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1708025539291/work/aten/src/ATen/native/TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
output = results[0]
pred_boxes = output['instances'].pred_boxes[:4].tensor.to('cpu').detach().to(torch.int32).numpy()
pred_classes = output['instances'].pred_classes[:4].to('cpu').detach().to(torch.int32).numpy()
pred_masks = output['instances'].pred_masks[:4].to('cpu').numpy()

# %%
img = batch[0]['image'].permute(1, 2, 0).numpy()
img = np.ascontiguousarray(img)

h_w = output['instances'].image_size
img = cv2.resize(img, h_w[::-1])

_ = plt.figure(figsize=(12, 10))
plt.imshow(img[..., ::-1])

# %%
img_draw = img.copy()

for box in pred_boxes:
    img_draw = cv2.rectangle(img_draw, box[:2], box[2:], (0, 225, 0), 2)
    #print(box[:2], box[2:])

_ = plt.figure(figsize=(12, 10))
plt.imshow(img_draw[..., ::-1])

# %%
mask = np.zeros(pred_masks.shape[1:])

for i in range(pred_masks.shape[0]):
    mask = np.logical_or(mask, pred_masks[i])

# %%
_ = plt.figure(figsize=(12, 10))
plt.imshow(mask, cmap='gray')
