# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt
import torch

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances

# %%
dataset = 'cityscapes'
annot_dir = './cityscapes/annotations'
imgs_dir = './cityscapes'

for split in ['train', 'val']: 
    annot_path = os.path.join(annot_dir, f'instancesonly_filtered_gtFine_{split}.json')
    d_name = dataset + f'_{split}'
    register_coco_instances(d_name, {}, annot_path, imgs_dir)

# Load dataset
dataset_dicts = DatasetCatalog.get('cityscapes_val')
metadata = MetadataCatalog.get('cityscapes_val')
# Out:
# [03/21 17:32:23 d2.data.datasets.coco]: Loaded 500 images in COCO format from ./cityscapes/annotations/instancesonly_filtered_gtFine_val.json

# %%
#ln -s /Users/giakhang/Downloads/output_yolof_uni_matcher ./

# %%
import argparse

class Args(argparse.Namespace):
    config_file='khang_net/configs/yolof/yolof_resnet_50_1x.py'
    eval_only=False
    num_gpus=1
    num_machines=1
    resume=False

args = Args()

# %%
from detectron2.model_zoo import get_config
from detectron2.config import LazyConfig
from detectron2.config.instantiate import instantiate


cfg = LazyConfig.load("khang_net/configs/yolof/yolof_resnet_50_1x.py")
cfg.train.device = 'mps'
cfg.dataloader.evaluator.dataset_name = 'cityscapes_train'
cfg.dataloader.train.dataset.names = 'cityscapes_train'
cfg.dataloader.test.dataset.names = 'cityscapes_val'
cfg.dataloader.train.total_batch_size = 1
cfg.dataloader.train.mapper.use_instance_mask = True


cfg.model.num_classes = 9

# %%
yolof = instantiate(cfg.model)
yolof.to(cfg.train.device)
# Out:
# YOLOF(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#     )
#   )
#   (encoder): DilatedEncoder(
#     (lateral_conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#     (lateral_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fpn_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dilated_encoder_blocks): Sequential(
#       (0): Bottleneck(
#         (conv1): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv3): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv3): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (2): Bottleneck(
#         (conv1): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv3): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (3): Bottleneck(
#         (conv1): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(8, 8), dilation=(8, 8))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (conv3): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (decoder): YOLOFDecoder(
#     (cls_subnet): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (bbox_subnet): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU(inplace=True)
#     )
#     (cls_score): Conv2d(512, 45, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bbox_pred): Conv2d(512, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (object_pred): Conv2d(512, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (anchor_generator): YOLOFAnchorGenerator(
#     (cell_anchors): BufferList()
#   )
#   (anchor_matcher): UniformMatcher()
# )

# %%
from detectron2.checkpoint import DetectionCheckpointer
DetectionCheckpointer(yolof).load('./output_yolof_uni_matcher/model_final.pth')
# Out:
# [03/21 17:35:52 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_yolof_uni_matcher/model_final.pth ...
# {'trainer': {'iteration': 22499,
#   'hooks': {'LRScheduler': {'base_lrs': [0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.002505,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.03,
#      0.03,
#      0.0075,
#      0.03,
#      0.0075,
#      0.03,
#      0.0075],
#     'last_epoch': 22500}},
#   'optimizer': {'state': {0: {'momentum_buffer': tensor([[[[ 1.8792e-03]],
#
#               [[ 3.0471e-03]],
#
#               [[ 4.8321e-03]],
#
#               ...,
#
#               [[ 3.3197e-03]],
#
#               [[ 5.6482e-03]],
#
#               [[ 3.2420e-03]]],
#
#
#              [[[ 1.3980e-03]],
#
#               [[-9.7014e-05]],
#
#               [[ 2.2398e-03]],
#
#               ...,
#
#               [[ 1.4876e-03]],
#
#               [[ 3.6891e-03]],
#
#               [[ 1.3657e-03]]],
#
#
#              [[[ 8.3374e-04]],
#
#               [[ 1.1610e-03]],
#
#               [[ 2.2056e-03]],
#
#               ...,
#
#               [[ 1.1375e-03]],
#
#               [[ 1.9583e-03]],
#
#               [[ 1.0042e-03]]],
#
#
#              ...,
#
#
#              [[[ 1.3814e-03]],
#
#               [[ 1.1434e-03]],
#
#               [[ 8.8762e-04]],
#
#               ...,
#
#               [[ 7.3474e-04]],
#
#               [[ 2.5384e-03]],
#
#               [[ 9.6440e-04]]],
#
#
#              [[[-3.6154e-04]],
#
#               [[ 5.0893e-04]],
#
#               [[ 4.2578e-04]],
#
#               ...,
#
#               [[ 9.9551e-04]],
#
#               [[ 3.8072e-04]],
#
#               [[ 7.4908e-04]]],
#
#
#              [[[-1.7868e-04]],
#
#               [[ 5.1143e-04]],
#
#               [[ 1.5965e-03]],
#
#               ...,
#
#               [[ 1.3044e-03]],
#
#               [[ 1.9319e-03]],
#
#               [[ 1.1200e-03]]]])},
#     1: {'momentum_buffer': tensor([[[[-1.3270e-03]],
#
#               [[ 3.6034e-04]],
#
#               [[ 5.7958e-04]],
#
#               ...,
#
#               [[ 2.3186e-04]],
#
#               [[ 6.9712e-05]],
#
#               [[ 9.4484e-06]]],
#
#
#              [[[-5.6061e-04]],
#
#               [[ 5.5832e-04]],
#
#               [[-1.2912e-03]],
#
#               ...,
#
#               [[-2.0854e-03]],
#
#               [[-1.4041e-03]],
#
#               [[-4.4223e-04]]],
#
#
#              [[[ 2.1774e-04]],
#
#               [[ 3.2863e-04]],
#
#               [[ 5.5557e-04]],
#
#               ...,
#
#               [[ 7.8180e-04]],
#
#               [[ 1.0331e-03]],
#
#               [[ 7.3564e-04]]],
#
#
#              ...,
#
#
#              [[[-7.6556e-05]],
#
#               [[ 1.2006e-03]],
#
#               [[ 2.1584e-04]],
#
#               ...,
#
#               [[-3.2522e-03]],
#
#               [[ 4.7949e-04]],
#
#               [[-1.5645e-04]]],
#
#
#              [[[ 4.2074e-04]],
#
#               [[ 1.0966e-03]],
#
#               [[ 7.8654e-04]],
#
#               ...,
#
#               [[ 4.8879e-04]],
#
#               [[ 4.7090e-04]],
#
#               [[-1.1626e-04]]],
#
#
#              [[[-6.0433e-04]],
#
#               [[-1.6124e-03]],
#
#               [[-6.0327e-04]],
#
#               ...,
#
#               [[-7.1609e-04]],
#
#               [[-8.7862e-04]],
#
#               [[-5.3608e-04]]]])},
#     2: {'momentum_buffer': tensor([[[[ 4.9433e-04,  3.9526e-04,  3.1652e-04],
#                [-1.8207e-04,  1.2750e-04,  8.5768e-04],
#                [ 3.5014e-04,  1.1289e-03,  1.4182e-03]],
#
#               [[-3.5843e-04, -4.6045e-04,  1.3603e-04],
#                [-3.5463e-04, -2.8514e-04, -3.6711e-04],
#                [ 2.3143e-04,  1.8388e-04,  3.7530e-04]],
#
#               [[-2.6890e-04,  1.7349e-04,  2.5484e-04],
#                [-1.3019e-04,  2.8428e-04,  5.5381e-05],
#                [ 1.9545e-04,  3.2967e-04, -8.4025e-05]],
#
#               ...,
#
#               [[-4.5740e-04, -1.0861e-03, -8.8210e-04],
#                [ 1.0972e-04, -4.0773e-04, -4.2414e-04],
#                [-4.7619e-04, -2.9739e-04, -5.9487e-04]],
#
#               [[ 2.2734e-04,  2.4276e-04,  1.1085e-04],
#                [ 2.7105e-04,  2.5587e-05,  5.4261e-05],
#                [-1.1357e-04, -2.0889e-04, -3.3146e-04]],
#
#               [[ 1.5078e-05,  4.6722e-04,  5.2193e-05],
#                [ 5.9533e-05,  1.7347e-04, -2.9999e-05],
#                [ 9.3654e-05,  9.3347e-05, -4.8119e-05]]],
#
#
#              [[[-6.4259e-04, -3.2838e-04, -8.3337e-05],
#                [ 3.9886e-04,  1.9608e-04,  2.7401e-04],
#                [ 4.1702e-04, -5.5172e-05, -3.3986e-05]],
#
#               [[-2.0267e-04, -7.4291e-05,  2.2946e-05],
#                [ 1.9624e-04,  1.7600e-04,  1.9738e-04],
#                [ 1.3519e-04, -1.9031e-04, -2.3166e-04]],
#
#               [[ 1.2645e-04,  6.9124e-05, -1.9002e-04],
#                [ 8.5978e-05, -9.9133e-06,  5.7533e-05],
#                [-7.1409e-06,  6.4157e-05, -1.9122e-05]],
#
#               ...,
#
#               [[-1.2471e-03, -9.9719e-04, -5.6692e-04],
#                [-5.1431e-04, -1.1223e-04,  7.5177e-05],
#                [-9.8283e-04, -4.1442e-04, -2.4012e-04]],
#
#               [[-2.0549e-05, -4.9380e-05, -9.0148e-05],
#                [ 1.1269e-04,  6.7065e-05,  7.9798e-05],
#                [ 1.3098e-04,  2.4145e-04,  3.5235e-04]],
#
#               [[-4.2311e-05, -2.0526e-04,  4.7166e-05],
#                [-1.2832e-06, -1.2241e-04,  3.5324e-06],
#                [-1.6921e-04, -2.5247e-04, -1.0028e-04]]],
#
#
#              [[[-2.1611e-03, -5.6814e-04, -3.5722e-04],
#                [-2.8115e-03, -1.4323e-03,  2.3130e-04],
#                [-2.2610e-03, -6.2251e-04, -7.7147e-04]],
#
#               [[-1.2810e-03, -1.3584e-03, -1.5955e-03],
#                [-1.7893e-03, -1.2587e-03, -1.4647e-03],
#                [-2.0026e-03, -1.3354e-03, -1.1437e-03]],
#
#               [[ 6.6855e-04,  7.2992e-05, -1.1781e-04],
#                [ 2.1516e-04,  5.1611e-05, -8.6915e-05],
#                [-4.9976e-05,  1.8867e-04,  5.0115e-04]],
#
#               ...,
#
#               [[ 3.9094e-04,  5.4264e-05,  1.3070e-03],
#                [ 6.9978e-04,  4.8359e-04,  2.0751e-03],
#                [ 1.2836e-03,  2.3261e-04,  1.9719e-03]],
#
#               [[-1.6246e-04, -9.4054e-05,  5.5632e-05],
#                [-3.7767e-05, -1.3807e-04,  2.1895e-04],
#                [ 2.9176e-04,  1.6886e-04,  2.5914e-04]],
#
#               [[-7.3610e-04, -3.8243e-04, -3.9448e-05],
#                [-3.7292e-04, -2.2047e-05,  1.3627e-04],
#                [-2.3106e-04, -1.9428e-04,  1.4763e-04]]],
#
#
#              ...,
#
#
#              [[[ 1.3604e-03,  7.1627e-04,  9.4202e-04],
#                [ 1.3104e-03,  9.3992e-04,  5.1556e-04],
#                [ 1.2602e-03,  1.4541e-03,  8.5549e-04]],
#
#               [[ 6.5704e-04,  2.9882e-04,  5.2437e-04],
#                [ 2.3464e-04,  3.6820e-04,  4.1321e-04],
#                [-8.0885e-05,  2.2907e-04,  2.9260e-04]],
#
#               [[ 1.6160e-05,  8.6369e-05,  2.0284e-04],
#                [ 1.5488e-04, -2.5525e-05, -1.1891e-04],
#                [-4.9473e-05,  1.0337e-04, -1.0826e-04]],
#
#               ...,
#
#               [[ 1.0853e-03,  1.1146e-03,  6.2756e-04],
#                [ 5.5464e-04,  8.9987e-04,  1.4560e-03],
#                [ 8.5661e-04,  6.9100e-04,  1.1080e-03]],
#
#               [[ 2.9863e-04,  2.5828e-04,  2.8856e-04],
#                [ 1.9902e-04,  1.3420e-05,  2.4172e-04],
#                [ 4.2170e-05,  4.5684e-05,  4.3706e-05]],
#
#               [[-3.0023e-04,  2.0436e-04,  2.1118e-04],
#                [-1.6033e-05, -1.2646e-05, -2.7362e-05],
#                [-1.8700e-05,  5.4298e-05, -2.6554e-04]]],
#
#
#              [[[-7.9038e-04, -4.4579e-04, -4.3024e-04],
#                [-4.9722e-04, -5.3198e-04, -6.3847e-04],
#                [-5.2023e-04,  2.6618e-04, -8.9285e-05]],
#
#               [[ 5.8788e-05,  4.5685e-04,  7.0091e-04],
#                [-5.4292e-05, -1.0244e-05, -1.7654e-04],
#                [-6.0910e-04, -7.3976e-05, -2.7917e-04]],
#
#               [[-2.2721e-04,  6.6014e-05, -3.0038e-04],
#                [-2.8500e-04, -5.0502e-04, -7.2342e-07],
#                [-4.2257e-04, -2.1331e-04, -4.8151e-04]],
#
#               ...,
#
#               [[ 1.7939e-04,  3.3742e-04,  8.6668e-04],
#                [-3.9020e-04, -3.6470e-04, -9.9756e-05],
#                [-1.0789e-04, -8.2116e-04,  5.4034e-04]],
#
#               [[ 3.2872e-04,  4.2385e-04,  5.1872e-04],
#                [ 2.4054e-04,  2.5237e-04,  4.2613e-04],
#                [-7.6336e-05, -7.9816e-05, -2.0392e-05]],
#
#               [[-1.5893e-05,  5.5307e-04,  7.4262e-04],
#                [-1.0269e-04,  3.9610e-04,  2.7479e-04],
#                [-3.3985e-04,  1.6308e-04,  3.0219e-04]]],
#
#
#              [[[ 3.0027e-04,  5.1647e-04,  4.5237e-04],
#                [-8.0016e-05,  4.2930e-04,  3.5728e-04],
#                [ 3.3718e-04,  5.6077e-04, -3.9366e-04]],
#
#               [[ 8.9942e-04,  1.7464e-03,  1.1082e-03],
#                [ 6.9266e-04,  1.3296e-03,  9.9883e-04],
#                [ 8.7670e-04,  9.5168e-04,  6.3802e-04]],
#
#               [[-1.4256e-04,  1.1311e-04,  1.5983e-04],
#                [ 2.1024e-04,  2.7816e-04,  9.8246e-05],
#                [ 8.4153e-05,  1.2533e-04, -1.0686e-04]],
#
#               ...,
#
#               [[ 2.6205e-03,  3.3633e-03,  3.3297e-03],
#                [ 2.7055e-03,  2.7752e-03,  2.9212e-03],
#                [ 1.9765e-03,  2.4340e-03,  2.7790e-03]],
#
#               [[ 5.7812e-04,  6.3669e-04,  7.9477e-04],
#                [ 6.5648e-04,  7.7984e-04,  8.9290e-04],
#                [ 4.0399e-04,  6.3224e-04,  4.5486e-04]],
#
#               [[ 4.2798e-04,  7.2402e-04,  3.5714e-04],
#                [ 4.1175e-04,  2.5120e-04,  5.5356e-04],
#                [ 5.2043e-04,  2.3973e-04,  3.2357e-04]]]])},
#     3: {'momentum_buffer': tensor([[[[ 9.4109e-04]],
#
#               [[ 8.9275e-04]],
#
#               [[ 4.0181e-03]],
#
#               ...,
#
#               [[ 6.4179e-04]],
#
#               [[ 7.0422e-03]],
#
#               [[ 2.3367e-03]]],
#
#
#              [[[ 6.2963e-04]],
#
#               [[-7.5078e-05]],
#
#               [[ 2.6706e-03]],
#
#               ...,
#
#               [[ 4.9272e-04]],
#
#               [[ 5.1720e-03]],
#
#               [[ 3.0987e-03]]],
#
#
#              [[[ 1.4758e-03]],
#
#               [[-7.6717e-04]],
#
#               [[ 7.8832e-04]],
#
#               ...,
#
#               [[ 6.6530e-04]],
#
#               [[ 5.1503e-03]],
#
#               [[ 8.7310e-04]]],
#
#
#              ...,
#
#
#              [[[ 3.4709e-04]],
#
#               [[ 5.9450e-04]],
#
#               [[ 3.6994e-03]],
#
#               ...,
#
#               [[-3.7066e-05]],
#
#               [[ 4.2365e-03]],
#
#               [[ 2.5104e-03]]],
#
#
#              [[[ 1.0458e-03]],
#
#               [[-2.9069e-05]],
#
#               [[ 1.2006e-03]],
#
#               ...,
#
#               [[ 7.1192e-04]],
#
#               [[ 2.9874e-03]],
#
#               [[-2.2674e-04]]],
#
#
#              [[[ 2.8543e-04]],
#
#               [[ 6.0604e-05]],
#
#               [[ 1.5728e-03]],
#
#               ...,
#
#               [[ 1.2904e-03]],
#
#               [[ 7.7829e-03]],
#
#               [[ 2.7023e-03]]]])},
#     4: {'momentum_buffer': tensor([[[[ 4.7341e-04]],
#
#               [[ 4.6710e-05]],
#
#               [[ 1.4718e-04]],
#
#               ...,
#
#               [[-5.9626e-04]],
#
#               [[-6.6507e-04]],
#
#               [[-1.1432e-03]]],
#
#
#              [[[ 1.9975e-04]],
#
#               [[ 1.1512e-03]],
#
#               [[ 4.3089e-04]],
#
#               ...,
#
#               [[ 5.4167e-04]],
#
#               [[ 8.9894e-04]],
#
#               [[ 7.9994e-04]]],
#
#
#              [[[ 6.0602e-05]],
#
#               [[-5.8536e-05]],
#
#               [[ 1.4237e-04]],
#
#               ...,
#
#               [[-5.1886e-05]],
#
#               [[ 2.6684e-04]],
#
#               [[-9.4023e-05]]],
#
#
#              ...,
#
#
#              [[[ 7.8093e-04]],
#
#               [[-2.9972e-04]],
#
#               [[ 6.3056e-04]],
#
#               ...,
#
#               [[-1.5907e-03]],
#
#               [[-8.3895e-04]],
#
#               [[-8.1218e-04]]],
#
#
#              [[[-1.8520e-03]],
#
#               [[-8.8825e-04]],
#
#               [[-5.5359e-04]],
#
#               ...,
#
#               [[ 7.7394e-04]],
#
#               [[ 3.8282e-04]],
#
#               [[-6.8365e-04]]],
#
#
#              [[[ 1.8856e-03]],
#
#               [[ 5.6909e-04]],
#
#               [[ 2.6898e-03]],
#
#               ...,
#
#               [[ 4.9112e-04]],
#
#               [[-4.3818e-04]],
#
#               [[ 2.5728e-03]]]])},
#     5: {'momentum_buffer': tensor([[[[ 1.4369e-03,  1.2288e-03,  7.8635e-04],
#                [ 1.4116e-04,  7.6788e-04,  1.2305e-03],
#                [ 5.0862e-04,  5.6075e-04,  5.9477e-04]],
#
#               [[ 5.7732e-05, -7.1079e-04,  7.0921e-05],
#                [ 5.2695e-05,  1.9318e-04, -5.5535e-05],
#                [ 7.4199e-04,  1.2225e-03,  8.7536e-04]],
#
#               [[ 2.8201e-04,  2.0329e-04,  9.4033e-04],
#                [ 2.6001e-04,  2.6876e-05,  4.1280e-04],
#                [ 4.7734e-05,  2.8135e-05, -2.8416e-05]],
#
#               ...,
#
#               [[ 1.9867e-03,  2.8890e-03,  1.9452e-03],
#                [ 1.6516e-03,  2.1053e-03,  1.4676e-03],
#                [ 1.5097e-03,  1.3769e-03,  8.5279e-04]],
#
#               [[ 9.2529e-05,  1.4549e-04,  5.4842e-04],
#                [ 5.3418e-04,  5.8275e-04,  8.4444e-04],
#                [ 1.7206e-04,  1.0622e-04,  6.6289e-04]],
#
#               [[ 1.9574e-04,  1.4644e-03,  1.8177e-03],
#                [ 1.2768e-03,  1.4627e-03,  1.8455e-03],
#                [ 1.4235e-03,  1.3526e-03,  1.6873e-03]]],
#
#
#              [[[ 3.0110e-04, -8.5044e-05,  8.0096e-04],
#                [ 6.0916e-04,  6.2199e-04,  8.3125e-04],
#                [-3.0975e-05,  2.5649e-04,  9.9039e-04]],
#
#               [[-2.8478e-05, -1.0597e-03,  7.0738e-04],
#                [-3.7621e-04, -7.7668e-04, -9.3607e-04],
#                [ 7.7593e-04, -9.8135e-04, -1.0078e-03]],
#
#               [[ 4.8171e-04,  8.8347e-05,  1.3039e-04],
#                [-8.9314e-06, -1.7482e-04,  7.9494e-05],
#                [-6.0749e-04, -4.1079e-04, -2.6501e-04]],
#
#               ...,
#
#               [[ 2.5700e-03,  2.3791e-03,  3.7886e-04],
#                [ 2.8090e-03,  3.2693e-03,  4.1900e-04],
#                [ 1.5421e-03,  2.2642e-03, -3.5450e-04]],
#
#               [[ 4.0523e-04,  5.1718e-05, -3.2685e-04],
#                [-4.0087e-04, -2.7093e-04, -3.2400e-04],
#                [ 6.3950e-05,  2.8321e-04, -4.7735e-06]],
#
#               [[ 2.2076e-03,  2.3774e-03,  1.4042e-03],
#                [ 6.5689e-04,  3.6565e-04,  1.0741e-03],
#                [ 1.0511e-03,  6.6195e-05, -1.7217e-03]]],
#
#
#              [[[-3.5139e-04,  3.4467e-05,  1.1062e-04],
#                [-4.6598e-04, -2.0014e-04,  2.9049e-04],
#                [ 1.0074e-04,  2.9718e-04,  3.7513e-04]],
#
#               [[-9.6603e-05,  4.0593e-04,  3.6939e-04],
#                [-4.6573e-04, -1.9393e-04, -1.8622e-04],
#                [ 1.3118e-04, -2.2509e-04, -8.9012e-05]],
#
#               [[-4.3889e-04, -6.0957e-04,  2.2444e-04],
#                [-6.4988e-05, -3.8395e-04,  2.0699e-04],
#                [ 1.8519e-04, -2.2724e-04, -4.8998e-04]],
#
#               ...,
#
#               [[-3.2731e-04,  1.2832e-04, -1.8958e-04],
#                [-1.1143e-03, -4.7400e-04, -5.1941e-04],
#                [-7.4141e-04, -1.3619e-03, -1.2430e-03]],
#
#               [[ 5.5296e-04,  1.5001e-04,  3.5513e-04],
#                [-4.8856e-04,  8.7301e-05,  1.2506e-04],
#                [ 2.7944e-04, -1.6814e-04, -4.3382e-04]],
#
#               [[ 8.8493e-05,  2.6329e-04,  8.0032e-05],
#                [ 5.4049e-04,  3.7581e-04,  2.1038e-04],
#                [ 1.5237e-04,  6.2028e-04,  5.3127e-04]]],
#
#
#              ...,
#
#
#              [[[ 1.0761e-03,  1.5612e-03,  1.0953e-03],
#                [ 1.1597e-03,  1.7058e-03,  6.2620e-04],
#                [ 8.6153e-04,  6.4636e-04,  1.1261e-03]],
#
#               [[ 8.9742e-04,  8.4638e-04,  2.7735e-04],
#                [ 8.3589e-04,  2.2614e-03,  1.0029e-03],
#                [ 1.3368e-03,  8.1549e-04,  5.0300e-04]],
#
#               [[ 2.7934e-04,  2.1852e-04,  2.8659e-04],
#                [ 1.6846e-04, -1.7315e-04, -1.3436e-04],
#                [ 2.3486e-04, -6.1216e-05, -3.8347e-04]],
#
#               ...,
#
#               [[ 7.8407e-04,  1.5195e-03,  1.7354e-03],
#                [ 7.5195e-04,  1.2524e-04,  1.2875e-03],
#                [ 1.1805e-03,  2.1302e-04,  1.2546e-03]],
#
#               [[ 2.9971e-04, -1.6745e-04,  4.1830e-04],
#                [ 1.5413e-03, -4.3896e-04,  3.5351e-04],
#                [ 2.0168e-04, -1.7566e-04,  9.9437e-05]],
#
#               [[ 1.3186e-03,  1.5925e-03,  1.2674e-03],
#                [ 1.8410e-03,  1.0260e-03,  1.0591e-03],
#                [ 1.6804e-03,  1.2776e-03,  4.5040e-04]]],
#
#
#              [[[-2.2462e-04,  1.7636e-04,  3.0902e-04],
#                [-9.5551e-04, -1.2099e-03, -9.6106e-04],
#                [-1.0798e-03, -8.7409e-04, -4.4008e-04]],
#
#               [[-4.2873e-04, -3.2457e-05, -1.6521e-04],
#                [-1.2402e-04, -2.6532e-04,  1.5690e-04],
#                [-1.2009e-03, -7.5310e-04, -3.4228e-05]],
#
#               [[-3.0231e-04, -6.6116e-05, -2.1739e-04],
#                [ 6.5562e-04,  4.0410e-04, -2.1493e-04],
#                [ 1.7601e-04,  4.4185e-04,  6.1686e-05]],
#
#               ...,
#
#               [[ 2.6655e-04, -1.1532e-03,  2.7899e-04],
#                [-3.9385e-04, -1.2530e-03, -2.2170e-04],
#                [ 1.2425e-04, -2.9432e-04, -3.8568e-04]],
#
#               [[-8.9032e-04, -1.8291e-04, -5.4862e-04],
#                [-5.7876e-04,  6.6249e-05,  4.1436e-05],
#                [-6.9728e-05, -4.2872e-04, -2.3317e-05]],
#
#               [[-8.4519e-04, -9.8604e-04, -5.8304e-04],
#                [-2.9878e-04, -1.4035e-04,  1.8703e-04],
#                [ 9.5760e-04,  5.2186e-04, -1.3276e-04]]],
#
#
#              [[[ 1.1771e-03,  5.6156e-04,  1.6485e-03],
#                [ 1.6821e-04,  4.9104e-04,  6.8420e-04],
#                [ 1.2121e-03,  2.5797e-04,  8.0092e-04]],
#
#               [[ 3.6156e-04,  4.9813e-04,  1.3865e-03],
#                [-2.6042e-04,  5.2716e-04,  7.0733e-04],
#                [-1.6184e-04, -4.4510e-05,  2.8405e-04]],
#
#               [[ 5.4497e-04,  2.2995e-04,  9.5669e-05],
#                [ 5.1082e-04,  8.2641e-04,  2.4455e-04],
#                [ 1.1673e-04,  5.6784e-04,  5.9270e-04]],
#
#               ...,
#
#               [[ 1.1752e-03,  1.5339e-03,  1.7467e-03],
#                [ 1.3327e-03,  1.6035e-03,  1.7364e-03],
#                [ 1.9241e-03,  1.8775e-03,  1.8983e-03]],
#
#               [[ 1.9772e-04,  7.9896e-04,  1.2101e-03],
#                [-1.7352e-04, -9.8224e-05,  3.7527e-04],
#                [ 8.2396e-04,  5.5682e-04, -7.3046e-05]],
#
#               [[ 2.2165e-03,  1.6931e-03,  1.7188e-03],
#                [ 1.7718e-03,  2.5165e-03,  2.0075e-03],
#                [ 2.6032e-03,  2.2334e-03,  2.5826e-03]]]])},
#     6: {'momentum_buffer': tensor([[[[ 8.2671e-04]],
#
#               [[ 4.9392e-04]],
#
#               [[ 9.9683e-04]],
#
#               ...,
#
#               [[ 3.3455e-03]],
#
#               [[-5.5864e-04]],
#
#               [[ 4.0860e-03]]],
#
#
#              [[[ 1.2964e-03]],
#
#               [[ 6.0042e-04]],
#
#               [[ 6.9731e-04]],
#
#               ...,
#
#               [[ 5.4073e-04]],
#
#               [[ 5.3021e-04]],
#
#               [[ 1.0334e-03]]],
#
#
#              [[[ 6.2590e-04]],
#
#               [[ 1.3851e-03]],
#
#               [[-2.6604e-06]],
#
#               ...,
#
#               [[ 6.7113e-04]],
#
#               [[-6.5219e-04]],
#
#               [[ 1.0656e-03]]],
#
#
#              ...,
#
#
#              [[[ 2.2940e-04]],
#
#               [[ 3.4491e-03]],
#
#               [[ 1.4471e-04]],
#
#               ...,
#
#               [[ 3.3921e-04]],
#
#               [[-5.2272e-04]],
#
#               [[ 1.0084e-03]]],
#
#
#              [[[ 3.6701e-04]],
#
#               [[ 2.0901e-04]],
#
#               [[ 1.2252e-04]],
#
#               ...,
#
#               [[-2.4015e-04]],
#
#               [[-1.2952e-04]],
#
#               [[-2.2214e-04]]],
#
#
#              [[[-4.8106e-06]],
#
#               [[ 3.5096e-04]],
#
#               [[ 2.7096e-04]],
#
#               ...,
#
#               [[ 3.1717e-05]],
#
#               [[-7.9175e-06]],
#
#               [[ 2.5420e-04]]]])},
#     7: {'momentum_buffer': tensor([[[[-3.3588e-03]],
#
#               [[-1.1750e-04]],
#
#               [[-2.4489e-03]],
#
#               ...,
#
#               [[ 2.3082e-04]],
#
#               [[-2.7153e-05]],
#
#               [[-9.0043e-04]]],
#
#
#              [[[-2.5979e-04]],
#
#               [[-2.8818e-04]],
#
#               [[ 4.7168e-05]],
#
#               ...,
#
#               [[-1.7951e-05]],
#
#               [[ 4.0735e-06]],
#
#               [[-4.3401e-05]]],
#
#
#              [[[ 1.1145e-04]],
#
#               [[ 8.0021e-04]],
#
#               [[ 7.9542e-05]],
#
#               ...,
#
#               [[ 1.5674e-03]],
#
#               [[ 6.5734e-04]],
#
#               [[ 1.1226e-03]]],
#
#
#              ...,
#
#
#              [[[-5.3689e-04]],
#
#               [[-1.6864e-04]],
#
#               [[-2.4083e-04]],
#
#               ...,
#
#               [[ 5.4247e-04]],
#
#               [[ 1.6589e-04]],
#
#               [[-7.2235e-06]]],
#
#
#              [[[-3.8066e-04]],
#
#               [[-4.5597e-04]],
#
#               [[ 6.0745e-04]],
#
#               ...,
#
#               [[ 2.1359e-04]],
#
#               [[ 2.1176e-04]],
#
#               [[-7.8796e-05]]],
#
#
#              [[[-1.0286e-03]],
#
#               [[-4.8872e-04]],
#
#               [[-8.4459e-04]],
#
#               ...,
#
#               [[ 5.1468e-04]],
#
#               [[ 1.2825e-04]],
#
#               [[-1.4988e-03]]]])},
#     8: {'momentum_buffer': tensor([[[[ 1.0494e-04,  6.3019e-05, -9.8767e-05],
#                [ 3.3280e-04,  2.2630e-04,  1.6651e-04],
#                [ 6.8885e-05, -1.3422e-04, -5.0504e-04]],
#
#               [[ 5.2407e-05, -5.4819e-05, -9.9585e-05],
#                [-1.1155e-04, -3.8628e-05, -1.0220e-04],
#                [-2.1587e-05,  9.7889e-06,  4.8403e-05]],
#
#               [[-4.2918e-04, -5.6843e-04, -2.3458e-04],
#                [-1.9727e-04,  1.0340e-04, -8.0604e-05],
#                [-2.8508e-04, -1.2988e-04, -8.6646e-04]],
#
#               ...,
#
#               [[-3.4027e-05, -1.2290e-04, -2.1721e-04],
#                [-9.1691e-05, -6.6982e-05, -4.2126e-05],
#                [-2.9413e-05, -8.4792e-05, -4.1956e-05]],
#
#               [[ 7.4653e-06, -3.2058e-05, -2.4652e-05],
#                [-1.0809e-04,  6.3235e-05,  4.0461e-05],
#                [-1.6230e-04, -1.0386e-04, -1.1740e-04]],
#
#               [[ 7.5178e-04,  7.3360e-04,  3.5742e-04],
#                [ 7.4127e-04,  6.4082e-04,  2.7708e-04],
#                [ 5.3163e-04,  2.6638e-04,  1.0963e-04]]],
#
#
#              [[[-5.1663e-04, -5.1284e-04, -8.3453e-04],
#                [-6.7973e-04, -1.4234e-03, -1.3913e-03],
#                [-1.8981e-03, -2.0510e-03, -1.6038e-03]],
#
#               [[-1.4560e-04, -1.4708e-04, -2.5576e-04],
#                [-2.1330e-04, -4.4103e-04, -2.3705e-04],
#                [ 9.3754e-05,  1.1343e-04,  1.0856e-04]],
#
#               [[-2.2439e-03, -1.9774e-03, -3.5904e-03],
#                [-1.7490e-03, -1.8996e-03, -3.4035e-03],
#                [-2.5721e-03, -1.6615e-03, -2.6389e-03]],
#
#               ...,
#
#               [[-1.6848e-04, -2.1721e-04, -2.6821e-04],
#                [-3.0622e-04, -4.0142e-04, -2.8837e-04],
#                [-7.4779e-05, -9.3456e-05, -1.5373e-05]],
#
#               [[-4.6059e-04, -8.1349e-04, -7.6531e-04],
#                [-5.3874e-04, -9.6544e-04, -8.6990e-04],
#                [-6.0831e-04, -5.9649e-04, -6.0983e-04]],
#
#               [[-5.8020e-03, -5.8746e-03, -5.8812e-03],
#                [-6.4449e-03, -6.4328e-03, -5.9143e-03],
#                [-5.9664e-03, -5.9289e-03, -5.9542e-03]]],
#
#
#              [[[-2.8470e-04, -3.5620e-04, -1.8431e-04],
#                [ 1.5544e-04,  3.2658e-04,  1.7390e-05],
#                [ 3.2132e-04,  5.5073e-04,  6.8722e-04]],
#
#               [[ 4.6730e-05,  8.1960e-05,  6.8141e-05],
#                [ 1.9560e-05, -2.3378e-05, -2.5533e-05],
#                [ 7.2442e-05,  4.8766e-05,  1.4719e-04]],
#
#               [[-1.5779e-04, -4.3581e-04, -6.2876e-05],
#                [-5.9123e-05, -2.8665e-04, -5.6648e-04],
#                [ 8.4933e-04, -1.9272e-04, -7.4465e-06]],
#
#               ...,
#
#               [[-3.4661e-04,  1.6809e-04,  1.6338e-04],
#                [-5.0770e-06, -8.6325e-05, -3.5414e-05],
#                [-5.2902e-05, -2.2740e-04, -3.6843e-05]],
#
#               [[ 4.0357e-05,  7.2538e-07, -1.4518e-04],
#                [ 2.3074e-04,  3.4951e-04, -1.7253e-04],
#                [ 1.6791e-04,  5.0771e-04,  3.3389e-04]],
#
#               [[ 6.5388e-05,  2.6271e-04,  3.5184e-04],
#                [ 1.0039e-03,  1.0489e-03,  8.0327e-04],
#                [ 7.2723e-04,  1.0989e-03,  9.0385e-04]]],
#
#
#              ...,
#
#
#              [[[ 5.2478e-04, -1.2215e-04,  2.7173e-04],
#                [-1.4057e-04, -5.2961e-04, -4.4287e-04],
#                [ 3.5890e-04,  1.9533e-04,  8.2265e-05]],
#
#               [[ 1.8287e-04,  7.4515e-05,  2.0415e-04],
#                [-1.8145e-05,  2.0907e-04,  6.9819e-05],
#                [ 1.1643e-05, -3.6471e-05,  4.6036e-05]],
#
#               [[ 1.4862e-03,  6.3778e-04,  1.8807e-03],
#                [ 1.4026e-03,  1.3026e-03,  1.5345e-03],
#                [-1.6609e-04,  1.4974e-04,  9.5881e-04]],
#
#               ...,
#
#               [[ 7.8596e-05, -9.6222e-05,  3.3628e-05],
#                [ 4.0346e-04,  2.4435e-04,  9.9708e-05],
#                [ 8.9206e-05,  5.2272e-05,  6.1054e-05]],
#
#               [[ 3.8461e-04,  4.5539e-04,  5.6210e-05],
#                [ 1.0598e-04,  2.0655e-04, -2.8818e-05],
#                [ 3.1678e-04,  2.9358e-04,  5.0797e-04]],
#
#               [[ 1.7994e-03,  2.6347e-03,  2.4283e-03],
#                [ 2.2197e-03,  2.2436e-03,  2.8067e-03],
#                [ 2.2122e-03,  2.5266e-03,  3.0793e-03]]],
#
#
#              [[[ 5.0496e-05,  8.1404e-04,  7.3711e-04],
#                [ 1.3379e-03,  3.1327e-04,  4.4637e-05],
#                [ 3.0010e-04, -1.9856e-04,  6.0740e-04]],
#
#               [[ 1.6028e-04,  1.1687e-04,  7.3595e-05],
#                [ 1.2231e-04,  5.0755e-05,  2.6884e-05],
#                [-2.0164e-05,  1.2112e-04, -2.8534e-06]],
#
#               [[ 1.2065e-05, -2.8150e-06,  1.2625e-03],
#                [ 9.0494e-04, -7.8047e-04,  1.4776e-03],
#                [ 8.0089e-04, -4.9744e-04,  2.4705e-03]],
#
#               ...,
#
#               [[ 5.4926e-04,  5.5676e-04,  5.9044e-04],
#                [ 5.4568e-05,  5.6059e-04,  2.2879e-04],
#                [ 3.2626e-05,  5.3180e-04, -3.8423e-05]],
#
#               [[ 1.9423e-05, -2.4280e-04, -2.3429e-04],
#                [-3.4840e-04, -2.3106e-05,  4.9285e-04],
#                [-6.3597e-04, -1.0977e-04, -7.8124e-04]],
#
#               [[ 1.4194e-03,  1.2457e-03,  2.1627e-03],
#                [ 1.2155e-03,  1.4102e-03,  1.1414e-03],
#                [ 5.5151e-04,  5.9807e-04,  1.7186e-04]]],
#
#
#              [[[ 1.2761e-04,  3.0420e-04, -1.0233e-04],
#                [ 1.0400e-03,  1.1169e-03,  8.2773e-04],
#                [ 9.4456e-04,  6.7156e-04,  1.2280e-03]],
#
#               [[ 8.0709e-05, -4.1365e-05,  5.0134e-05],
#                [ 1.3052e-04,  7.9505e-05,  1.4288e-04],
#                [ 1.0509e-04,  1.5351e-04,  1.3176e-04]],
#
#               [[ 8.7025e-04, -8.2659e-05,  6.2965e-04],
#                [ 1.1802e-03,  2.5229e-04, -3.1624e-05],
#                [ 1.9186e-03, -6.1251e-04, -3.9002e-04]],
#
#               ...,
#
#               [[ 1.0584e-04,  2.6860e-04,  2.3039e-04],
#                [-9.0502e-05,  3.2895e-05,  2.7234e-04],
#                [ 1.4938e-04,  8.6033e-05,  6.7710e-05]],
#
#               [[-1.5600e-04, -2.8284e-04, -2.3414e-04],
#                [ 2.1090e-04, -9.9999e-05, -2.6806e-05],
#                [-1.9647e-05,  2.2734e-04,  2.8093e-04]],
#
#               [[ 1.8186e-03,  6.5795e-04,  1.4853e-03],
#                [ 1.4473e-03,  1.3580e-03,  1.2166e-03],
#                [ 1.0048e-03,  9.4062e-04,  1.0861e-03]]]])},
#     9: {'momentum_buffer': tensor([[[[ 1.2357e-04]],
#
#               [[ 4.4694e-04]],
#
#               [[ 3.8944e-04]],
#
#               ...,
#
#               [[ 9.9894e-04]],
#
#               [[ 1.7090e-03]],
#
#               [[ 1.5470e-03]]],
#
#
#              [[[-1.2675e-04]],
#
#               [[ 1.1516e-03]],
#
#               [[ 3.0201e-04]],
#
#               ...,
#
#               [[ 1.2939e-03]],
#
#               [[ 3.1526e-03]],
#
#               [[ 2.9205e-03]]],
#
#
#              [[[ 3.2755e-04]],
#
#               [[ 2.2859e-03]],
#
#               [[ 1.9347e-03]],
#
#               ...,
#
#               [[ 1.0361e-03]],
#
#               [[ 5.2525e-03]],
#
#               [[ 1.7897e-03]]],
#
#
#              ...,
#
#
#              [[[ 1.3876e-04]],
#
#               [[ 5.0853e-05]],
#
#               [[ 4.6535e-04]],
#
#               ...,
#
#               [[-4.0361e-04]],
#
#               [[ 1.3859e-03]],
#
#               [[ 1.4547e-03]]],
#
#
#              [[[ 1.6325e-04]],
#
#               [[-1.2240e-03]],
#
#               [[-6.0551e-04]],
#
#               ...,
#
#               [[ 1.5996e-03]],
#
#               [[ 1.9756e-03]],
#
#               [[-1.0885e-04]]],
#
#
#              [[[-2.5660e-07]],
#
#               [[-1.4159e-05]],
#
#               [[-1.7734e-06]],
#
#               ...,
#
#               [[ 1.5509e-05]],
#
#               [[ 3.8969e-05]],
#
#               [[ 3.5743e-05]]]])},
#     10: {'momentum_buffer': tensor([[[[-1.4668e-03]],
#
#               [[-1.2008e-03]],
#
#               [[-1.3604e-03]],
#
#               ...,
#
#               [[-4.3404e-04]],
#
#               [[-1.9699e-03]],
#
#               [[-3.9738e-03]]],
#
#
#              [[[-1.0978e-03]],
#
#               [[-5.5591e-05]],
#
#               [[-2.3640e-03]],
#
#               ...,
#
#               [[-6.1351e-04]],
#
#               [[ 3.4106e-05]],
#
#               [[ 2.6019e-05]]],
#
#
#              [[[ 1.3917e-03]],
#
#               [[ 2.6859e-05]],
#
#               [[-4.8434e-04]],
#
#               ...,
#
#               [[-1.0853e-03]],
#
#               [[ 9.3546e-04]],
#
#               [[ 7.6528e-04]]],
#
#
#              ...,
#
#
#              [[[-3.7176e-03]],
#
#               [[-1.2288e-03]],
#
#               [[-2.2551e-03]],
#
#               ...,
#
#               [[-1.2041e-03]],
#
#               [[-1.8485e-03]],
#
#               [[-2.2181e-03]]],
#
#
#              [[[-3.8802e-04]],
#
#               [[ 1.2445e-03]],
#
#               [[-1.7782e-03]],
#
#               ...,
#
#               [[ 2.4744e-03]],
#
#               [[ 1.9850e-03]],
#
#               [[ 2.0159e-03]]],
#
#
#              [[[-5.8955e-05]],
#
#               [[ 8.9541e-04]],
#
#               [[ 1.1701e-03]],
#
#               ...,
#
#               [[ 1.5754e-04]],
#
#               [[-3.3243e-04]],
#
#               [[ 9.2869e-05]]]])},
#     11: {'momentum_buffer': tensor([[[[ 2.0096e-04, -9.0003e-05,  1.8019e-04],
#                [-1.9325e-04,  4.7555e-05,  6.2666e-04],
#                [ 7.7266e-04,  1.0145e-03,  7.0515e-04]],
#
#               [[ 9.5998e-05, -7.1659e-04, -6.9598e-04],
#                [ 1.5132e-04,  8.1377e-05, -1.9940e-04],
#                [ 2.3592e-04,  6.5471e-04,  1.1437e-03]],
#
#               [[-2.3321e-04, -7.6321e-04,  5.5333e-04],
#                [ 7.1062e-04, -9.6046e-05,  5.6598e-04],
#                [ 6.9658e-04, -4.0749e-04,  3.5714e-04]],
#
#               ...,
#
#               [[ 9.9677e-04,  8.7872e-04,  6.0892e-04],
#                [ 1.4934e-03,  1.8630e-03,  9.9259e-04],
#                [ 8.0523e-04,  7.9663e-04,  5.1576e-04]],
#
#               [[-4.4227e-04,  5.0999e-04,  1.0017e-03],
#                [-8.8442e-04,  9.7818e-04,  7.7832e-04],
#                [ 3.1500e-04, -1.2005e-04,  1.5409e-03]],
#
#               [[-1.7931e-04, -3.6390e-04,  7.2538e-04],
#                [ 7.0134e-04,  1.9710e-04,  4.3699e-04],
#                [-2.3644e-04,  1.4333e-04,  8.3042e-05]]],
#
#
#              [[[-2.6547e-04,  2.1620e-04,  2.6500e-04],
#                [ 1.5594e-04,  3.0491e-04, -1.2635e-04],
#                [ 7.2994e-04,  2.4822e-04,  7.9648e-05]],
#
#               [[ 8.1958e-05,  2.7611e-05, -4.6556e-04],
#                [ 1.1003e-04, -6.3515e-05, -2.1560e-04],
#                [ 2.8947e-04, -2.6303e-04,  2.5184e-04]],
#
#               [[ 1.7978e-04, -4.3592e-05, -5.4359e-04],
#                [ 3.1013e-04, -1.8378e-04, -8.5554e-05],
#                [-1.8134e-04, -8.1012e-05,  1.5991e-04]],
#
#               ...,
#
#               [[ 8.3359e-04,  7.6294e-04,  1.1554e-03],
#                [ 8.9670e-04,  9.5184e-04,  7.9854e-04],
#                [ 8.1494e-04,  1.1938e-03,  1.0879e-03]],
#
#               [[ 2.6156e-04,  9.4905e-04, -3.6969e-06],
#                [-5.0506e-04,  5.3303e-05,  1.0663e-03],
#                [ 3.3388e-04, -2.0925e-04, -1.0903e-04]],
#
#               [[ 4.6141e-06,  1.8047e-04,  5.0641e-04],
#                [ 2.0777e-04,  7.4536e-05,  3.9098e-04],
#                [ 5.8651e-04,  2.3269e-05,  1.7894e-04]]],
#
#
#              [[[-2.9539e-04, -6.0655e-05, -9.8733e-04],
#                [-2.5777e-04,  5.8389e-05, -1.2573e-04],
#                [ 1.4699e-05, -1.1706e-04,  2.0215e-04]],
#
#               [[-1.2839e-04,  9.4715e-05, -4.3326e-05],
#                [ 6.6388e-04,  6.6080e-04,  9.3828e-05],
#                [ 8.8364e-04,  2.5704e-04, -4.0500e-05]],
#
#               [[ 5.2483e-04,  9.0934e-04, -2.9529e-05],
#                [ 4.8828e-04,  2.7707e-04,  4.3948e-04],
#                [ 2.5122e-05, -3.1282e-04,  2.4984e-04]],
#
#               ...,
#
#               [[ 2.4706e-03,  2.0588e-03,  1.0767e-03],
#                [ 8.0496e-04,  1.1021e-03,  1.8332e-03],
#                [-6.9830e-04, -4.8495e-05,  6.1193e-04]],
#
#               [[ 6.2641e-04,  9.7485e-05,  1.2735e-03],
#                [ 5.0543e-04,  4.1446e-04,  2.3944e-04],
#                [ 1.2276e-04, -3.5330e-04,  1.2927e-05]],
#
#               [[ 2.7472e-04,  8.2775e-05, -2.0128e-04],
#                [ 5.4399e-04,  2.4521e-04, -7.2511e-04],
#                [-6.9498e-05, -2.6006e-04, -6.3376e-04]]],
#
#
#              ...,
#
#
#              [[[-1.3602e-03, -9.9001e-04, -3.9601e-04],
#                [-2.0154e-03, -1.3803e-03, -5.4926e-04],
#                [-1.2916e-03, -8.4185e-04, -9.7695e-04]],
#
#               [[-1.1341e-03, -8.6600e-04, -1.0010e-03],
#                [ 5.8519e-04, -6.6858e-04, -4.3467e-04],
#                [ 3.2565e-04, -7.5976e-05, -1.0648e-03]],
#
#               [[-1.1070e-03, -1.5863e-03, -2.3155e-03],
#                [-1.0640e-04, -1.8348e-03, -6.7199e-04],
#                [-1.6054e-03, -1.9633e-03, -2.3957e-03]],
#
#               ...,
#
#               [[-2.0980e-03, -2.6786e-03, -1.8720e-03],
#                [-1.8978e-03, -2.6649e-03, -1.2984e-03],
#                [-2.5916e-03, -2.5001e-03, -1.8788e-03]],
#
#               [[ 1.7768e-03,  4.2819e-04, -7.0210e-04],
#                [ 5.8289e-04, -1.0267e-03, -2.6654e-03],
#                [-4.1244e-04,  2.8676e-05, -3.2652e-04]],
#
#               [[-1.0693e-04, -2.0492e-04, -6.9571e-04],
#                [-8.3655e-04, -6.3703e-04, -7.7412e-05],
#                [-9.9740e-05, -1.4711e-04,  2.2504e-04]]],
#
#
#              [[[-1.7468e-04, -2.8776e-04, -2.6627e-04],
#                [-5.2537e-05,  4.6367e-04,  1.1283e-04],
#                [-7.7495e-05,  8.5979e-04,  4.5743e-04]],
#
#               [[ 2.1240e-06, -6.7331e-04,  2.9209e-05],
#                [-2.6271e-04, -1.9797e-04, -1.0780e-03],
#                [-7.9527e-04,  5.7296e-04, -2.5117e-04]],
#
#               [[ 3.7237e-05, -1.8980e-04,  5.4742e-04],
#                [ 3.2011e-04,  4.3986e-04,  1.4647e-04],
#                [-7.7869e-04, -8.0539e-05,  1.0562e-03]],
#
#               ...,
#
#               [[ 5.1390e-04,  1.9059e-04,  4.6217e-04],
#                [ 3.7853e-04,  1.7363e-03,  8.5881e-04],
#                [-3.1524e-05,  1.1393e-03,  1.1959e-03]],
#
#               [[-3.8316e-04, -7.0336e-04, -6.0096e-04],
#                [ 9.1398e-05, -2.1303e-04, -4.3264e-04],
#                [-1.9017e-04,  8.2324e-04,  7.3142e-05]],
#
#               [[ 3.0933e-04, -5.1035e-04,  8.9598e-05],
#                [ 1.6190e-04,  2.7877e-04, -9.3103e-05],
#                [-5.2235e-04,  2.8051e-04, -3.1904e-04]]],
#
#
#              [[[-9.2079e-05, -4.1916e-04, -3.7899e-04],
#                [-8.9864e-05,  2.6765e-04,  3.9846e-05],
#                [ 3.1687e-04, -6.6741e-04,  2.1464e-04]],
#
#               [[ 2.6985e-04, -1.5842e-05,  9.4211e-05],
#                [-3.6225e-04, -6.6065e-04,  6.8652e-05],
#                [ 1.7910e-04,  2.6362e-04, -1.9866e-04]],
#
#               [[ 5.1573e-04,  3.4535e-05,  1.1006e-03],
#                [ 5.8669e-04, -5.2632e-04,  2.5854e-04],
#                [ 1.1258e-03,  2.0194e-04,  6.4958e-04]],
#
#               ...,
#
#               [[ 6.5250e-04,  8.7847e-04,  1.5755e-03],
#                [ 5.2912e-04,  2.2036e-03,  1.4778e-03],
#                [ 1.7744e-03,  2.2693e-03,  8.7003e-04]],
#
#               [[-4.6649e-04, -3.9089e-04,  1.3651e-03],
#                [-1.2532e-03,  4.5272e-04, -7.0092e-04],
#                [ 7.7703e-04,  3.5192e-04,  4.5613e-05]],
#
#               [[ 8.7425e-04, -6.6306e-04,  7.4349e-04],
#                [ 6.6660e-04, -3.5918e-04,  9.5745e-04],
#                [ 2.6322e-04,  1.4955e-04,  7.4845e-04]]]])},
#     12: {'momentum_buffer': tensor([[[[ 1.0663e-03]],
#
#               [[ 7.6943e-04]],
#
#               [[ 9.7668e-04]],
#
#               ...,
#
#               [[ 2.6130e-03]],
#
#               [[ 2.0012e-03]],
#
#               [[ 1.4719e-03]]],
#
#
#              [[[ 2.7119e-03]],
#
#               [[ 3.3986e-04]],
#
#               [[ 6.9143e-04]],
#
#               ...,
#
#               [[ 4.8348e-03]],
#
#               [[ 3.4289e-03]],
#
#               [[ 3.6284e-03]]],
#
#
#              [[[ 1.0307e-03]],
#
#               [[-3.7080e-04]],
#
#               [[ 7.2801e-04]],
#
#               ...,
#
#               [[ 8.5905e-04]],
#
#               [[ 8.2087e-04]],
#
#               [[ 1.8962e-03]]],
#
#
#              ...,
#
#
#              [[[-5.3541e-05]],
#
#               [[-1.2826e-04]],
#
#               [[ 3.4708e-04]],
#
#               ...,
#
#               [[ 1.5997e-03]],
#
#               [[-3.2442e-04]],
#
#               [[ 2.2368e-03]]],
#
#
#              [[[ 2.0575e-03]],
#
#               [[ 7.1504e-05]],
#
#               [[-3.0811e-05]],
#
#               ...,
#
#               [[ 2.7695e-03]],
#
#               [[ 1.0185e-03]],
#
#               [[ 1.3628e-03]]],
#
#
#              [[[-5.0927e-05]],
#
#               [[-9.3104e-05]],
#
#               [[-2.2907e-04]],
#
#               ...,
#
#               [[-6.2388e-04]],
#
#               [[-1.5078e-04]],
#
#               [[-9.1593e-05]]]])},
#     13: {'momentum_buffer': tensor([[[[ 0.0015]],
#
#               [[ 0.0012]],
#
#               [[ 0.0018]],
#
#               ...,
#
#               [[ 0.0007]],
#
#               [[ 0.0024]],
#
#               [[ 0.0023]]],
#
#
#              [[[-0.0004]],
#
#               [[-0.0006]],
#
#               [[-0.0003]],
#
#               ...,
#
#               [[-0.0003]],
#
#               [[-0.0006]],
#
#               [[-0.0008]]],
#
#
#              [[[-0.0003]],
#
#               [[ 0.0006]],
#
#               [[ 0.0006]],
#
#               ...,
#
#               [[ 0.0003]],
#
#               [[ 0.0008]],
#
#               [[ 0.0001]]],
#
#
#              ...,
#
#
#              [[[ 0.0002]],
#
#               [[ 0.0014]],
#
#               [[ 0.0014]],
#
#               ...,
#
#               [[ 0.0008]],
#
#               [[ 0.0013]],
#
#               [[ 0.0014]]],
#
#
#              [[[ 0.0007]],
#
#               [[ 0.0013]],
#
#               [[-0.0001]],
#
#               ...,
#
#               [[ 0.0009]],
#
#               [[ 0.0004]],
#
#               [[ 0.0012]]],
#
#
#              [[[ 0.0004]],
#
#               [[-0.0022]],
#
#               [[-0.0004]],
#
#               ...,
#
#               [[-0.0012]],
#
#               [[-0.0011]],
#
#               [[-0.0010]]]])},
#     14: {'momentum_buffer': tensor([[[[-1.4525e-03]],
#
#               [[-6.7427e-04]],
#
#               [[-9.2409e-04]],
#
#               ...,
#
#               [[-5.8695e-04]],
#
#               [[-1.3602e-04]],
#
#               [[-2.0307e-04]]],
#
#
#              [[[ 1.0449e-03]],
#
#               [[ 1.1670e-03]],
#
#               [[ 7.9143e-04]],
#
#               ...,
#
#               [[-1.3366e-04]],
#
#               [[ 5.2873e-04]],
#
#               [[-5.2748e-04]]],
#
#
#              [[[ 8.5989e-04]],
#
#               [[ 1.1715e-03]],
#
#               [[ 4.5130e-05]],
#
#               ...,
#
#               [[ 1.1901e-04]],
#
#               [[ 1.2087e-03]],
#
#               [[ 1.2663e-03]]],
#
#
#              ...,
#
#
#              [[[-9.3930e-04]],
#
#               [[-9.3365e-04]],
#
#               [[ 1.0626e-04]],
#
#               ...,
#
#               [[-1.3043e-03]],
#
#               [[-3.8518e-04]],
#
#               [[ 2.6350e-04]]],
#
#
#              [[[ 4.2470e-04]],
#
#               [[ 2.7055e-04]],
#
#               [[-1.8495e-04]],
#
#               ...,
#
#               [[-6.0414e-04]],
#
#               [[-1.0644e-03]],
#
#               [[ 3.4007e-04]]],
#
#
#              [[[ 5.4040e-05]],
#
#               [[ 9.2499e-05]],
#
#               [[-8.9984e-04]],
#
#               ...,
#
#               [[-7.1636e-04]],
#
#               [[ 1.2026e-03]],
#
#               [[-2.0017e-04]]]])},
#     15: {'momentum_buffer': tensor([[[[-1.2358e-05, -2.0143e-04, -5.6601e-05],
#                [-1.4563e-04, -6.6277e-05, -5.4786e-04],
#                [-4.4142e-05, -1.6683e-04, -3.6709e-04]],
#
#               [[ 3.5381e-04, -1.4209e-04, -9.5807e-05],
#                [ 1.7820e-04,  1.5818e-04,  1.8365e-04],
#                [ 1.3134e-04,  5.5362e-04,  7.6345e-05]],
#
#               [[-6.7066e-05,  2.1326e-05, -1.4879e-05],
#                [ 4.9376e-05, -1.1679e-04, -1.8517e-05],
#                [ 1.2931e-04,  1.1207e-04,  5.7922e-06]],
#
#               ...,
#
#               [[-5.3001e-04, -1.0687e-04, -3.8955e-04],
#                [-4.9185e-04,  1.3187e-04,  5.2426e-05],
#                [-4.4752e-04, -5.3070e-04, -3.9126e-04]],
#
#               [[ 5.3403e-04,  1.3429e-04, -6.9183e-05],
#                [ 1.7573e-04,  1.6276e-04,  3.9548e-04],
#                [ 1.1598e-04, -1.7045e-04, -7.3782e-07]],
#
#               [[-4.9896e-04, -2.9605e-04, -1.4649e-04],
#                [-7.7910e-04, -6.5006e-04, -1.8078e-04],
#                [-6.3282e-04, -4.9939e-04, -4.7043e-04]]],
#
#
#              [[[ 9.8578e-06,  1.2053e-04,  6.7463e-06],
#                [ 2.9005e-04,  1.6031e-04,  1.6361e-04],
#                [ 1.9486e-04,  5.6014e-04,  5.5236e-04]],
#
#               [[-1.0100e-04,  1.6702e-04,  6.2325e-04],
#                [ 3.8106e-04,  3.2119e-04,  2.4576e-04],
#                [ 4.4119e-04,  6.7842e-04,  4.8767e-04]],
#
#               [[ 6.2759e-04,  3.9709e-04,  1.2666e-04],
#                [ 1.8421e-04,  6.0534e-05,  2.2076e-04],
#                [ 1.3873e-04,  3.5886e-05,  1.6350e-04]],
#
#               ...,
#
#               [[ 5.1010e-04,  5.5370e-04,  1.3771e-04],
#                [ 3.3888e-05,  6.3228e-04,  2.0455e-04],
#                [ 3.6884e-04,  3.8808e-04,  5.9341e-04]],
#
#               [[ 2.0960e-04, -1.0132e-04,  4.3920e-05],
#                [ 2.4808e-05,  6.5147e-05,  4.6543e-05],
#                [ 1.9495e-04,  1.3014e-04,  1.8942e-04]],
#
#               [[ 2.2254e-04,  1.9431e-04, -1.6985e-05],
#                [ 3.2249e-05, -2.8358e-05,  8.0967e-05],
#                [ 2.7729e-04,  1.7135e-04,  2.2493e-04]]],
#
#
#              [[[-2.0648e-04,  3.2210e-05,  1.3059e-04],
#                [-1.1088e-03, -2.4821e-05, -8.7090e-04],
#                [-1.0834e-03, -6.9347e-04, -9.2782e-04]],
#
#               [[-9.2378e-04, -1.4877e-04,  8.8082e-04],
#                [-4.3958e-04, -1.8670e-04, -9.1902e-04],
#                [-1.7742e-03, -1.7408e-03, -1.0481e-03]],
#
#               [[ 4.1782e-04,  4.7049e-04,  6.7450e-04],
#                [ 4.6698e-04,  1.4365e-04,  5.0961e-04],
#                [ 3.1601e-04,  2.8093e-04,  2.3490e-04]],
#
#               ...,
#
#               [[ 6.1028e-04, -7.4611e-05, -4.6593e-04],
#                [-3.9403e-04, -7.0531e-04, -1.0189e-03],
# ...
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [60]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [61]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [62]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [63]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [64]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [65]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [66]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [67]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [68]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [69]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [70]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [71]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [72]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [73]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [74]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [75]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [76]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [77]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [78]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [79]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [80]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [81]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [82]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [83]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [84]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [85]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [86]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [87]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [88]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [89]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [90]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [91]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [92]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [93]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [94]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [95]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [96]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [97]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [98]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [99]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [100]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [101]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [102]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [103]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [104]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [105]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [106]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [107]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [108]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [109]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [110]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [111]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [112]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [113]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [114]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [115]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [116]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [117]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [118]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [119]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [120]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [121]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [122]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [123]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [124]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [125]},
#     {'lr': 0.0003,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.03,
#      'params': [126]},
#     {'lr': 7.5e-05,
#      'weight_decay': 0.0,
#      'momentum': 0.9,
#      'dampening': 0,
#      'nesterov': False,
#      'maximize': False,
#      'foreach': None,
#      'differentiable': False,
#      'initial_lr': 0.0075,
#      'params': [127]}]}},
#  'iteration': 22499}

# %%
dataloader = instantiate(cfg.dataloader.train)
# Out:
# [03/21 17:36:12 d2.data.datasets.coco]: Loading ./cityscapes/annotations/instancesonly_filtered_gtFine_train.json takes 16.31 seconds.
# [03/21 17:36:12 d2.data.datasets.coco]: Loaded 2975 images in COCO format from ./cityscapes/annotations/instancesonly_filtered_gtFine_train.json
# [03/21 17:36:12 d2.data.build]: Removed 10 images with no usable annotations. 2965 images left.
# [03/21 17:36:12 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=[800], max_size=1333, sample_style='choice'), RandomFlip()]
# [03/21 17:36:12 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/21 17:36:12 d2.data.common]: Serializing 2965 elements to byte tensors and concatenating them all ...
# [03/21 17:36:14 d2.data.common]: Serialized dataset takes 97.08 MiB
# [03/21 17:36:14 d2.data.build]: Making batched data loader with batch_size=1

# %%
# show image
batch = next(iter(dataloader))
img = batch[0]['image']
img = np.ascontiguousarray(img.permute(1, 2, 0), dtype=np.uint8)

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 12))
plt.imshow(img)

# %%
batch[0]['image'].shape
# Out:
# torch.Size([3, 667, 1333])

# %%
batch[0]
# Out:
# {'file_name': './cityscapes/leftImg8bit/train/zurich/zurich_000015_000019_leftImg8bit.png',
#  'height': 1024,
#  'width': 2048,
#  'image_id': 118,
#  'image': tensor([[[195, 195, 219,  ...,  76, 100, 127],
#           [181, 178, 196,  ...,  95, 114, 138],
#           [166, 168, 175,  ..., 117, 128, 142],
#           ...,
#           [ 48,  47,  47,  ...,  28,  27,  26],
#           [ 49,  46,  45,  ...,  34,  32,  31],
#           [ 49,  46,  45,  ...,  37,  36,  34]],
#
#          [[179, 187, 223,  ..., 107, 140, 168],
#           [172, 170, 197,  ..., 121, 148, 170],
#           [167, 167, 176,  ..., 143, 159, 169],
#           ...,
#           [ 54,  54,  54,  ...,  31,  29,  28],
#           [ 54,  52,  53,  ...,  37,  35,  33],
#           [ 54,  52,  53,  ...,  40,  39,  37]],
#
#          [[149, 173, 202,  ...,  83, 114, 149],
#           [137, 148, 167,  ..., 110, 131, 153],
#           [138, 137, 129,  ..., 133, 148, 157],
#           ...,
#           [ 41,  41,  41,  ...,  21,  19,  19],
#           [ 42,  40,  39,  ...,  26,  25,  22],
#           [ 42,  40,  39,  ...,  30,  29,  28]]], dtype=torch.uint8),
#  'instances': Instances(num_instances=5, image_height=667, image_width=1333, fields=[gt_boxes: Boxes(tensor([[ 937.,  215., 1032.,  405.],
#          [1127.,  226., 1197.,  328.],
#          [1093.,  146., 1329.,  663.],
#          [ 419.,  228.,  973.,  633.],
#          [   3.,   96., 1329.,  375.]])), gt_classes: tensor([0, 0, 1, 1, 7]), gt_masks: PolygonMasks(num_instances=5)])}

# %%
yolof.training = False
output = yolof(batch)

# %%
# Plot output
output = output[0]

# %%
output
# Out:
# {'instances': Instances(num_instances=43, image_height=1024, image_width=2048, fields=[pred_boxes: Boxes(tensor([[1481.7119,  324.7553, 1564.0613,  614.1691],
#          [1510.6835,  367.3512, 1579.7189,  615.1976],
#          [ 687.5151,  608.8310,  850.8311,  886.4498],
#          [1466.5470,  294.4022, 1581.6390,  656.9669],
#          [1011.7743,  545.4153, 1528.4208,  862.4450],
#          [1110.5857,  615.1275, 1410.8234,  778.8293],
#          [1855.7783,  746.0972, 2017.0912,  938.6445],
#          [1671.4982,  301.9105, 2008.8885,  822.7227],
#          [1812.6415,  673.1505, 2019.3864,  931.4313],
#          [1909.6118,  214.1202, 2015.9913,  446.9745],
#          [ 837.8521,  359.5796, 1315.4055,  566.8978],
#          [ 926.9759,  248.2921, 1084.5404,  361.7641],
#          [ 657.4901,  547.8503,  889.0180,  716.7059],
#          [ 906.2571,  249.1815, 1089.4081,  313.0736],
#          [1175.0942,  613.1435, 1479.7775,  762.4247],
#          [1640.3344,  307.3752, 1997.8231,  749.1675],
#          [1738.2389,  257.0729, 1982.1860,  513.3971],
#          [ 772.5798,  404.6688, 1070.6903,  577.8799],
#          [1739.3447,  288.0045, 1940.4854,  629.8930],
#          [1839.9015,  306.0816, 1964.6807,  676.4672],
#          [1935.8881,  183.6350, 2020.3948,  490.5437],
#          [ 974.7381,  294.8611, 1050.9753,  439.2607],
#          [ 763.6945,  350.1368,  878.0683,  479.1395],
#          [1948.8503,  179.1472, 2021.0015,  487.6233],
#          [1145.1831,  564.1378, 1509.6886,  811.4305],
#          [ 683.1627,  567.3250,  742.2301,  774.6255],
#          [ 691.5609,  356.4835, 1162.9009,  588.7386],
#          [ 939.9491,  254.8101, 1065.0233,  405.6671],
#          [1228.9728,  291.2726, 1455.4060,  396.5115],
#          [ 722.9878,  248.4443,  751.9410,  309.5415],
#          [ 683.9248,  367.5320, 1107.7461,  615.0168],
#          [1885.4128,  811.7321, 2047.7305,  956.8557],
#          [ 758.3130,  371.4528,  820.1613,  452.5401],
#          [ 692.5173,  453.1279,  844.4942,  693.3812],
#          [ 841.1911,  241.2049, 1110.7216,  349.3643],
#          [ 133.8399,  654.3149,  272.2731,  819.5082],
#          [ 115.6741,  184.8642,  179.3117,  310.3535],
#          [ 652.0430,  223.4648,  724.5572,  355.4049],
#          [1304.0238,  340.3056, 1475.4989,  588.1232],
#          [ 815.0885,  322.8666,  913.7341,  423.0074],
#          [1480.5880,  403.0748, 1569.2292,  579.4739],
#          [ 863.1864,  340.9603,  924.1506,  463.7455],
#          [ 297.9377,  149.7407,  517.5070,  243.2788]], device='mps:0',
#         grad_fn=<IndexBackward0>)), scores: tensor([0.8816, 0.7305, 0.4446, 0.2939, 0.2222, 0.2204, 0.1620, 0.1391, 0.1311,
#          0.1311, 0.1302, 0.1198, 0.1164, 0.1040, 0.1038, 0.1013, 0.0971, 0.0967,
#          0.0955, 0.0930, 0.0911, 0.0885, 0.0854, 0.0839, 0.0808, 0.0802, 0.0793,
#          0.0753, 0.0747, 0.0729, 0.0723, 0.0721, 0.0709, 0.0708, 0.0700, 0.0681,
#          0.0677, 0.0665, 0.0664, 0.0576, 0.0556, 0.0534, 0.0513],
#         device='mps:0', grad_fn=<IndexBackward0>), pred_classes: tensor([8, 8, 7, 8, 7, 7, 1, 7, 1, 1, 7, 7, 7, 7, 7, 0, 1, 6, 1, 8, 6, 8, 7, 1,
#          7, 1, 7, 7, 7, 8, 6, 1, 7, 6, 7, 1, 8, 8, 6, 7, 8, 1, 1],
#         device='mps:0')])}

# %%
img.shape
# Out:
# (667, 1333, 3)

# %%
boxes = output['instances'].pred_boxes[:5].tensor.to('cpu')
classes = output['instances'].pred_classes[:5].to('cpu')

# %%
import torch
import numpy as np

boxes = boxes.to(torch.int32).numpy()
classes
# Out:
# tensor([8, 8, 7, 8, 7])

# %%
img = batch[0]['image'].permute(1, 2, 0).numpy()
img = np.ascontiguousarray(img)

h_w = output['instances'].image_size
img = cv2.resize(img, h_w[::-1])

for box in boxes:
    img = cv2.rectangle(img, box[:2], box[2:], (0, 225, 0), 2)
    #print(box[:2], box[2:])

_ = plt.figure(figsize=(12, 10))
plt.imshow(img[..., ::-1])

# %% [markdown]
# # Input size in the entire pipeline

# %%
images = yolof.preprocess_image(batch)

print('Original image size: {} x {}'.format(batch[0]['width'], batch[0]['height']))
print('Image size in dataloader: {} x {}'.format(images.image_sizes[0][1], images.image_sizes[0][0]))
print('Image size after preprocessing (preparing to feed to model): {} x {}'.format(images.tensor.size(-1), images.tensor.size(-2)))
# Out:
# Original image size: 2048 x 1024
# Image size in dataloader: 1333 x 667
# Image size after preprocessing (preparing to feed to model): 1333 x 667

# %%
images = yolof.preprocess_image(batch)

print('Image size after preprocessing (preparing to feed to model): {} x {}'.format(images.tensor.size(-1), images.tensor.size(-2)))
# Out:
# Image size after preprocessing (preparing to feed to model): 1333 x 667

# %%
features = yolof.backbone(images.tensor)
features = features['res5']

print('Feature maps size after feeding to backbone (s = s/32): {} x {}'.format(features.size(-1), features.size(-2)))
# Out:
# Feature maps size after feeding to backbone (s = s/32): 42 x 21

# %%
box_cls, box_delta = yolof.decoder(yolof.encoder(features))
anchors = yolof.anchor_generator([features])

print('Box class size: {} x {}'.format(box_cls.size(-1), box_cls.size(-2)))
print('Box delta size: {} x {}'.format(box_delta.size(-1), box_delta.size(-2)))
print('Anchors shape: {} x {}'.format(anchors[0][0].tensor.size(-1), anchors[0][0].tensor.size(0)))

assert anchors[0][0].tensor.size(0) == 5 * box_cls.size(-1) * box_cls.size(-2)
# Out:
# Box class size: 42 x 21
# Box delta size: 42 x 21
# Anchors shape: 4 x 4410

# %%
results = yolof.inference([box_cls], [box_delta], anchors, images.image_sizes)
result = results[0]

print('Prediction on image has shape (this shape is the shape before preprocessing): {} x {}'.format(*result.image_size[::-1]))
# Out:
# Prediction on image has shape (this shape is the shape before preprocessing): 1333 x 667

# %%
img_tmp = images.tensor[0].to(torch.uint8).permute(1, 2, 0).to('cpu').numpy().copy()

for box in result.pred_boxes[:5]:
    box = box.to('cpu').to(torch.int32).numpy()
    img_tmp = cv2.rectangle(img_tmp, box[:2], box[2:], (0, 0, 255), 2)

fig = plt.figure(figsize=(12, 12))
plt.imshow(img_tmp[..., ::-1])

print('Result image size: {} x {}'.format(*result.image_size[::-1]))
print('Image size at this stage: {} x {}'.format(*img_tmp.shape[:2][::-1]))
# Out:
# Result image size: 1333 x 667
# Image size at this stage: 1333 x 667

# %%
from detectron2.modeling.postprocessing import detector_postprocess

processed_results = []

for results_per_image, input_per_image, image_size in zip(
    results, batch, images.image_sizes):
    height = input_per_image.get('height', image_size[0])
    width = input_per_image.get('width', image_size[1])
    
    r = detector_postprocess(results_per_image, height, width)
    processed_results.append({'instances': r})

# %%
processed_result = processed_results[0]['instances']

img_size = processed_result.image_size

raw_img = batch[0]['image'].to(torch.uint8).permute(1, 2, 0).to('cpu').numpy().copy()
raw_img = cv2.resize(raw_img, img_size[::-1])

for box in processed_result.pred_boxes[:5]:
    box = box.to('cpu').to(torch.int32).numpy()
    raw_img = cv2.rectangle(raw_img, box[:2], box[2:], (0, 255, 0), 2)

fig = plt.figure(figsize=(12, 12))
plt.imshow(raw_img[..., ::-1])

print('Processed result image size: {} x {}'.format(*img_size[::-1]))
print('Image size after post-processing: {} x {}'.format(*raw_img.shape[:2][::-1]))
# Out:
# Processed result image size: 2048 x 1024
# Image size after post-processing: 2048 x 1024

# %% [markdown]
# # Simulate inference stage

# %%
images = yolof.preprocess_image(batch)
features = yolof.backbone(images.tensor)
features = features['res5']
box_cls, box_delta = yolof.decoder(yolof.encoder(features))
anchors = yolof.anchor_generator([features])
results = yolof.inference([box_cls], [box_delta], anchors, images.image_sizes)

# %%
images.image_sizes
# Out:
# [(402, 1333)]

# %%
features.shape
# Out:
# torch.Size([1, 2048, 13, 42])

# %%
results
# Out:
# [Instances(num_instances=8, image_height=402, image_width=1333, fields=[pred_boxes: Boxes(tensor([[406.2224, 193.8669, 464.0215, 225.5355],
#          [589.9467, 181.8413, 766.7061, 350.3064],
#          [323.5023, 186.2306, 348.2942, 221.2933],
#          [530.9360, 177.4620, 553.7035, 188.1650],
#          [565.8536, 168.3945, 587.0291, 186.7894],
#          [526.6335, 169.7064, 559.8585, 186.5175],
#          [522.2622, 173.1471, 563.5007, 190.2981],
#          [324.6994, 186.5236, 350.8427, 222.2042]], device='mps:0',
#         grad_fn=<IndexBackward0>)), scores: tensor([0.9661, 0.9293, 0.9105, 0.8441, 0.3992, 0.2076, 0.0964, 0.0759],
#         device='mps:0', grad_fn=<IndexBackward0>), pred_classes: tensor([7, 7, 0, 1, 1, 1, 1, 1], device='mps:0')])]

# %% [markdown]
# ## These lines above are viewed as ROI proposals

# %%
from detectron2.modeling.poolers import ROIPooler

# %%
pooler = ROIPooler(output_size=14, scales=(1.0/32,), sampling_ratio=0, pooler_type='ROIAlignV2')

# %%
proposal_boxes = [x.pred_boxes for x in results]

# %%
features = [features]

# %%
roi_maps = pooler(features, proposal_boxes)

# %%
roi_maps.shape
# Out:
# torch.Size([8, 2048, 14, 14])

# %%
roi_maps.device
# Out:
# device(type='mps', index=0)

# %%
from detectron2.modeling.roi_heads import MaskRCNNConvUpsampleHead
from detectron2.layers import ShapeSpec

# %%
mask_head = MaskRCNNConvUpsampleHead(input_shape=ShapeSpec(channels=2048, width=14, height=14),
                                     num_classes=9,
                                     conv_dims=[256])

# %%
mask_head
# Out:
# MaskRCNNConvUpsampleHead(
#   (deconv): ConvTranspose2d(2048, 256, kernel_size=(2, 2), stride=(2, 2))
#   (deconv_relu): ReLU()
#   (predictor): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
mask_head.to('mps')
# Out:
# MaskRCNNConvUpsampleHead(
#   (deconv): ConvTranspose2d(2048, 256, kernel_size=(2, 2), stride=(2, 2))
#   (deconv_relu): ReLU()
#   (predictor): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
x = mask_head.layers(roi_maps)

# %%
x.shape
# Out:
# torch.Size([8, 9, 28, 28])

# %% [markdown]
# # Simulate training stage

# %%
images = yolof.preprocess_image(batch)
features = yolof.backbone(images.tensor)
features = features['res5']
box_cls, box_delta = yolof.decoder(yolof.encoder(features))
anchors = yolof.anchor_generator([features])
proposals = yolof.inference([box_cls], [box_delta], anchors, images.image_sizes)
# Out:
# /Users/giakhang/miniconda3/envs/hope_to_public_net/lib/python3.9/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1708025539291/work/aten/src/ATen/native/TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# Do we need to label_and_sample_proposals????

# %%
from detectron2.modeling.roi_heads import MaskRCNNConvUpsampleHead
from detectron2.layers import ShapeSpec

mask_head = MaskRCNNConvUpsampleHead(input_shape=ShapeSpec(channels=2048, width=14, height=14),
                                     num_classes=9,
                                     conv_dims=[256])
mask_head.to('mps')
# Out:
# MaskRCNNConvUpsampleHead(
#   (deconv): ConvTranspose2d(2048, 256, kernel_size=(2, 2), stride=(2, 2))
#   (deconv_relu): ReLU()
#   (predictor): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
from detectron2.modeling.poolers import ROIPooler

pooler = ROIPooler(output_size=14, scales=(1.0/32,), sampling_ratio=0, pooler_type='ROIAlignV2')
pooler.to('mps')
# Out:
# ROIPooler(
#   (level_poolers): ModuleList(
#     (0): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#   )
# )

# %%
proposal_boxes = [x.pred_boxes.to('mps') for x in proposals]
box_features = pooler([features], proposal_boxes)
pred_mask_logits = mask_head.layers(box_features)

# %%
gt_instances = [x['instances'] for x in batch]

# %%
gt_masks = []

for instances_per_image in gt_instances:
    gt_masks_per_image = instances_per_image.gt_masks.crop_and_resize(
        instances_per_image.gt_boxes.tensor, 14)
    gt_masks.append(gt_masks_per_image.to(device='mps'))

# %%
gt_masks_per_image = gt_masks[0].to('cpu')

# %%
gt_masks_per_image.shape
# Out:
# torch.Size([5, 14, 14])
